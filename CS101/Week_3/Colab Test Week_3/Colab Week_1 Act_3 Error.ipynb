# %%
print("Natchanon")
print('Hello')
print(python colab )
# Out:
#   File "<ipython-input-1-7291b5950acb>", line 1
#     print(Natchanon ี")
#                     ^
# SyntaxError: invalid character 'ี' (U+0E35)

# %%
print (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-a39ac18537fc> in <cell line: 1>()
# ----> 1 print (1/0)
#
# ZeroDivisionError: division by zero

# %%
Nickname = (input("Enter you Nickname :"))
day = int(input("Enter you BirthDay :"))
month = int(input("Enter You Month :"))
year = int(input("Enter you Year :"))
old = int(input(("Enter you old :")))
tell = (input("enter you tell :"))
line_ID = input("Enter line ID :")
print("Nickname :",Nickname)
print(" day :",day)
print("month :",month)
print("Year :",year)
print("old : ",old)
print("tell :",tell)
print("Line ID",line_ID)
# Out:
# Enter you Nickname :Pungpond
# Enter you BirthDay :10
# Enter You Month :06
# Enter you Year :2548
# Enter you old :19
# enter you tell :0944388974
# Enter line ID :Sealpondsaypay
# Nickname : Pungpond
#  day : 10
# month : 6
# Year : 2548
# old :  19
# tell : 0944388974
# Line ID Sealpondsaypay
