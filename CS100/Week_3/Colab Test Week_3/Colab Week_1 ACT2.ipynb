# %%
#Natchanon Srileamonpiwat /  Student ID : 1670700044

# %%
Num1 = int(input("Enter Number 1 : "))
Num2 = int(input("Enter Number 2 : "))
print(Num1 ,"+", Num2 , "=" ,Num1+Num2)
print(Num1 ,"-", Num2 , "=" ,Num1-Num2)
print(Num1 ,"*", Num2 , "=" ,Num1*Num2)
print(Num1 ,"/", Num2 , "=" ,Num1/Num2)
# Out:
# Enter Number 1 : 5
# Enter Number 2 : 9
# 5 + 9 = 14
# 5 - 9 = -4
# 5 * 9 = 45
# 5 / 9 = 0.5555555555555556

# %%
data = int(input("Enter Data : "))
time = float(input("Enter Time :"))
print("Today is ",data ,"th and current time is ",time)
# Out:
# Enter Data : 1
# Enter Time :8.47
# Today is  1 th and current time is  8.47
